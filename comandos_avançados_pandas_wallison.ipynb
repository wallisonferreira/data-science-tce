# %% [markdown]
# <a href="https://colab.research.google.com/github/wallisonferreira/data-science-tce/blob/main/comandos_avan%C3%A7ados_pandas_wallison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Biblioteca Pandas - Analisando dados do Índice de Governança Municipal

# %% [markdown]
# Lançado em 2016, o Índice de Governança Municipal (IGM-CFA) consiste em uma métrica da governança pública nos municípios brasileiros a partir de três dimensões: Finanças, Gestão e Desempenho.
#
# Fonte: https://www.ipm.com.br/noticias/administracao-geral-noticias/indice-de-governanca-municipal-2021-clientes-ipm-sao-destaque-no-brasil/#:~:text=Lan%C3%A7ado%20em%202016%2C%20o%20%C3%8Dndice,%3A%20Finan%C3%A7as%2C%20Gest%C3%A3o%20e%20Desempenho.

# %%
import pandas as pd

# %%
url='https://drive.google.com/uc?id=1IJPSBCA5PtirkTjw831LxtWSnsjXUpw5'

df = pd.read_csv(url,sep=";")

# %%
#dados lidos corretamente???
df.head(10)
# Out:
#          regiao estado              municipio  codigo_mun  capital  \
# 0       SUDESTE     SP               ILHABELA     3520400        0
# 1       SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2           SUL     SC              BOMBINHAS     4202453        0
# 3       SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4  CENTRO-OESTE     DF               BRASILIA     5300108        1
# 5       SUDESTE     SP                 SANTOS     3548500        0
# 6       SUDESTE     SP             INDAIATUBA     3520509        0
# 7           SUL     RS                GRAMADO     4309100        0
# 8           SUL     SC     BALNEARIO CAMBORIU     4202008        0
# 9           SUL     SC             RIO DO SUL     4214805        0
#
#              porte  populacao    area       densidade_dem           pib  ...  \
# 0  Pequeno porte 2    32782,0  347,52   94,33126151012893    3256711,64  ...
# ...

# %% [markdown]
# # Conhecendo os dados
#
#
# *   head()
# *   tail()
# *   sample()
# *   shape()
# *   info()
# *   describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   regiao                       5570 non-null   object
#  1   estado                       5570 non-null   object
#  2   municipio                    5570 non-null   object
#  3   codigo_mun                   5570 non-null   int64
#  4   capital                      5570 non-null   int64
#  5   porte                        5570 non-null   object
#  6   populacao                    5570 non-null   object
#  7   area                         5570 non-null   object
#  8   densidade_dem                5570 non-null   object
#  9   pib                          5570 non-null   object
#  10  pib_pc                       5570 non-null   object
#  11  participacao_transf_receita  4893 non-null   object
#  12  servidores                   5233 non-null   object
# ...

# %% [markdown]
# Utilize o comando `df.head().T` para visuarlizar os dados invertendo a posição das colunas e linhas (matriz transposta)

# %%
df.sample(4).T
# Out:
#                                              4182                 2960  \
# regiao                                    SUDESTE             NORDESTE
# estado                                         SP                   PE
# municipio                         RIBEIRAO BRANCO           PARNAMIRIM
# codigo_mun                                3543006              2610400
# capital                                         0                    0
# porte                             Pequeno porte 1      Pequeno porte 2
# populacao                                 17430,0              21290,0
# area                                        697,5              2621,43
# densidade_dem                  24,989247311827956     8,12152145966133
# pib                                     308021,17            143317,16
# pib_pc                                   17024,33              6827,88
# participacao_transf_receita                   NaN                 76,0
# ...

# %%
df.describe()

# %% [markdown]
# #Conversão de tipos de dados
#
#
# *  astype(typo)
# *  pd.to_numeric(x, errors='coerce')

# %%
#df['area'].astype(float)

# %%
df['area'] = df['area'].str.replace(',','.').astype(float)
df['area'].head()
# Out:
# 0     347.52
# 1     179.95
# 2      35.92
# 3     409.53
# 4    5780.00
# Name: area, dtype: float64

# %%
df['populacao'] = df['populacao'].str.replace(',','.').astype(float)
df['populacao'].head()
# Out:
# 0      32782.0
# 1     129261.0
# 2      18052.0
# 3     822242.0
# 4    2977216.0
# Name: populacao, dtype: float64

# %%
#populacao vai causar outro tipo de problema. O que fazer? ignorar ou corrigir pontualmente?
df.loc[0,"nota_mat"] = "xxx"
#df.head()
df['nota_mat'] = df['nota_mat'].str.replace(',','.')
pd.to_numeric(df['nota_mat'], errors='coerce')
# Out:
# 0              NaN
# 1       499.911091
# 2       474.506731
# 3       514.204358
# 4       509.206006
#            ...
# 5565    458.921429
# 5566    442.091358
# 5567    426.578049
# 5568    437.482692
# 5569    407.050000
# Name: nota_mat, Length: 5570, dtype: float64

# %%
# transformação de coluna com valores errados - transformando os erros em NaN
df.loc[0, 'nota_mat'] = 'xxx'

df['nota_mat'] = df['nota_mat'].str.replace(',', '.')

pd.to_numeric(df['nota_mat'], errors='coerce')
# Out:
# 0              NaN
# 1       499.911091
# 2       474.506731
# 3       514.204358
# 4       509.206006
#            ...
# 5565    458.921429
# 5566    442.091358
# 5567    426.578049
# 5568    437.482692
# 5569    407.050000
# Name: nota_mat, Length: 5570, dtype: float64

# %%
#solução global
df = pd.read_csv(url, sep= ";", decimal=",")

# %%
df.sample(5)
# Out:
#         regiao estado            municipio  codigo_mun  capital  \
# 4727   SUDESTE     MG  SAO JOAO NEPOMUCENO     3162906        0
# 2421  NORDESTE     PI  SAO JOAO DA VARJOTA     2209955        0
# 3064   SUDESTE     MG         NACIP RAYDAN     3144201        0
# 1176       SUL     RS        RESTINGA SECA     4315503        0
# 455    SUDESTE     SP         BADY BASSITT     3504602        0
#
#                 porte  populacao    area  densidade_dem        pib  ...  \
# 4727  Pequeno porte 2    26439.0  407.43      64.892129  301146.97  ...
# 2421  Pequeno porte 1     4755.0  395.31      12.028535   19765.37  ...
# 3064  Pequeno porte 1     3270.0  233.49      14.004882   23542.40  ...
# 1176  Pequeno porte 1    16324.0  968.50      16.854930  322106.30  ...
# 455   Pequeno porte 1    16604.0  110.37     150.439431  258052.15  ...
#
#       gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 4727             484.07             8.97     497.098817    548.521302
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   regiao                       5570 non-null   object
#  1   estado                       5570 non-null   object
#  2   municipio                    5570 non-null   object
#  3   codigo_mun                   5570 non-null   int64
#  4   capital                      5570 non-null   int64
#  5   porte                        5570 non-null   object
#  6   populacao                    5570 non-null   float64
#  7   area                         5570 non-null   float64
#  8   densidade_dem                5570 non-null   float64
#  9   pib                          5570 non-null   float64
#  10  pib_pc                       5570 non-null   float64
#  11  participacao_transf_receita  4893 non-null   float64
# ...

# %% [markdown]
# # Seleção de Registros
#
#
# *   fatiamento de linhas: df[-2:], df[1], df[5:8]
# *   propriedade [loc e iloc](https://https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79): df.iloc[20:30], df.loc[1]
# *   seleção de colunas específicas df['indice_governanca'], df.indice_governanca

# %%
df[1:5]
# Out:
#          regiao estado              municipio  codigo_mun  capital  \
# 1       SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2           SUL     SC              BOMBINHAS     4202453        0
# 3       SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4  CENTRO-OESTE     DF               BRASILIA     5300108        1
#
#              porte  populacao     area  densidade_dem           pib  ...  \
# 1     Grande porte   129261.0   179.95     718.316199  7.373603e+06  ...
# 2  Pequeno porte 1    18052.0    35.92     502.561247  3.773573e+05  ...
# 3     Grande porte   822242.0   409.53    2007.769883  4.766853e+07  ...
# 4     Grande porte  2977216.0  5780.00     515.089273  1.753628e+08  ...
#
#    gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 1            1704.93            10.01     483.997625    542.760422
# 2            1370.96            10.44     472.105607    541.949533
# ...

# %%
#df.indice_governanca
df_cidade = df[['municipio','pib']]
df_cidade
# Out:
#                     municipio           pib
# 0                    ILHABELA  3.256712e+06
# 1         SANTANA DE PARNAIBA  7.373603e+06
# 2                   BOMBINHAS  3.773573e+05
# 3       SAO BERNARDO DO CAMPO  4.766853e+07
# 4                    BRASILIA  1.753628e+08
# ...                       ...           ...
# 5565             RIO DOS BOIS  2.713671e+04
# 5566       AXIXA DO TOCANTINS  8.020545e+04
# 5567               FILADELFIA  7.850072e+04
# 5568  PONTE ALTA DO TOCANTINS  5.914757e+04
# 5569             SILVANOPOLIS  7.773486e+04
#
# [5570 rows x 2 columns]

# %% [markdown]
# # Realizando Filtros
#
#
#
# *   loc: df.loc(df.porte = 0.5) ou df.loc[
#     (df.indice_governanca > 0.7) & (df.regiao == 'NORDESTE')]
# ]
# *   .isin
# *   subset
# *   query : df.query('indice_governanca < 0.7')
# *   np.select(codicao, acao, default)

# %%
df.query('indice_governanca > 0.7')
# Out:
#           regiao estado              municipio  codigo_mun  capital  \
# 0        SUDESTE     SP               ILHABELA     3520400        0
# 1        SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2            SUL     SC              BOMBINHAS     4202453        0
# 3        SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4   CENTRO-OESTE     DF               BRASILIA     5300108        1
# 5        SUDESTE     SP                 SANTOS     3548500        0
# 6        SUDESTE     SP             INDAIATUBA     3520509        0
# 7            SUL     RS                GRAMADO     4309100        0
# 8            SUL     SC     BALNEARIO CAMBORIU     4202008        0
# 9            SUL     SC             RIO DO SUL     4214805        0
# 10       SUDESTE     SP          SAO SEBASTIAO     3550704        0
# 11       SUDESTE     SP                JUNDIAI     3525904        0
# 12           SUL     SC         FLOR DO SERTAO     4205357        0
# ...

# %%
df.loc[(df.porte == 'Pequeno porte 1') & (df.estado.isin(["AC","PE"]))]
# Out:
#         regiao estado            municipio  codigo_mun  capital  \
# 1061  NORDESTE     PE              TRIUNFO     2615706        0
# 2038  NORDESTE     PE            DORMENTES     2605152        0
# 2172  NORDESTE     PE           PALMEIRINA     2610103        0
# 2391  NORDESTE     PE             MACHADOS     2609105        0
# 2509  NORDESTE     PE               JATOBA     2608057        0
# ...        ...    ...                  ...         ...      ...
# 4994  NORDESTE     PE       BELEM DE MARIA     2601508        0
# 4999  NORDESTE     PE       CHA DE ALEGRIA     2604403        0
# 5001  NORDESTE     PE            PRIMAVERA     2611408        0
# 5005  NORDESTE     PE  FERNANDO DE NORONHA     2605459        0
# 5007  NORDESTE     PE           PARANATAMA     2610301        0
#
#                 porte  populacao     area  densidade_dem        pib  ...  \
# 1061  Pequeno porte 1    15235.0   191.52      79.547828  100824.40  ...
# ...

# %%
#exemplo do np.select
import numpy as np
condicoes = [
    (df.indice_governanca >= 0.7) ,
    (df.indice_governanca >= 0.4) & (df.indice_governanca < 0.7),
    (df.indice_governanca < 0.4)
    ]
situacoes = ['A', 'B', 'C']
df['classificacao'] = np.select(condicoes, situacoes, default='Sem Informação')

# %%
import matplotlib.pyplot as plt
df["classificacao"].value_counts().plot(kind="barh")
plt.show()

# %%
df.sample(5)
# Out:
#         regiao estado      municipio  codigo_mun  capital            porte  \
# 34     SUDESTE     SP       BOTUCATU     3507506        0     Grande porte
# 3151  NORDESTE     PE       CARNAIBA     2603900        0  Pequeno porte 1
# 474        SUL     PR  FOZ DO IGUACU     4108304        0     Grande porte
# 1049   SUDESTE     MG            LUZ     3138807        0  Pequeno porte 1
# 1202       SUL     SC    NOVA VENEZA     4211603        0  Pequeno porte 1
#
#       populacao     area  densidade_dem         pib  ...  exp_anos_estudo  \
# 34     141032.0  1482.64      95.122214  3789753.72  ...            10.45
# 3151    19380.0   427.80      45.301543   114920.62  ...             9.41
# 474    263915.0   618.35     426.805207  9877009.86  ...            10.09
# 1049    18347.0  1171.66      15.658980   382147.70  ...             9.40
# 1202    14654.0   295.04      49.667842   469780.89  ...            10.62
#
# ...

# %%
df['classificacao'].value_counts()
# Out:
# B                 2868
# Sem Informação    2267
# C                  419
# A                   16
# Name: classificacao, dtype: int64

# %% [markdown]
# # Obtenção de métricas específicas de sumarização
#
#
# *   min
# *   max
# *   mean
# *   median
# *   sum
# *   count (não conta valores em branco)
# *   size()
# *  .quantile(0.25)
# *   mode

# %%
df.populacao.min()
# Out:
# 815.0

# %% [markdown]
# # Criação, alteração de nome e valores e remoção de Colunas
#
#
# *   df["novaColuna"] = valor
# *   df["coluna"] = df["coluna"]*df["coluna2"]
# *   df.rename(columns = {'col1': 'new_col1', 'col2': 'new_col2'},inplace = False)
# *   df.drop(columns='coluna', inplace=True)
# *   df.append({'col1': 'val1', 'col2: 'val2'}, ignore_index=True)
# *   df.insert(8, 'new_column', 'new_col_value')

# %%
df["teste"] = "nova coluna"

# %%
df["media_enem"] = (df["nota_ciencias"]+	df["nota_humanas"]+ df["nota_linguagem"]	+ df["nota_mat"] +	df["nota_redacao"])/5
df.head()
# Out:
#          regiao estado              municipio  codigo_mun  capital  \
# 0       SUDESTE     SP               ILHABELA     3520400        0
# 1       SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2           SUL     SC              BOMBINHAS     4202453        0
# 3       SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4  CENTRO-OESTE     DF               BRASILIA     5300108        1
#
#              porte  populacao     area  densidade_dem           pib  ...  \
# 0  Pequeno porte 2    32782.0   347.52      94.331262  3.256712e+06  ...
# 1     Grande porte   129261.0   179.95     718.316199  7.373603e+06  ...
# 2  Pequeno porte 1    18052.0    35.92     502.561247  3.773573e+05  ...
# 3     Grande porte   822242.0   409.53    2007.769883  4.766853e+07  ...
# 4     Grande porte  2977216.0  5780.00     515.089273  1.753628e+08  ...
#
#    nota_ciencias  nota_humanas  nota_linguagem    nota_mat  nota_redacao  \
# ...

# %%
df.drop(columns='teste', inplace=True)

# %% [markdown]
# criar uma coluna nivel_governabilidade que categoriza os municiopios em três classes:
#
#
# *   A -> indice_governanca >= 0.7
# *   B -> indice_governanca entre 0.4 e 0.7
# *   C -> os demais
#
# criar uma funcao e utilizar o método apply:
#
# df['coluna nivel_governabilidade'] = df['indice_governanca'].apply(funcao_classe_ig)

# %%
def funcao_classe_ig(ig):
  if(ig>=0.7):
    return "A"
  elif (ig>=0.4):
    return "B"
  else:
    return "C"

df['nivel_governabilidade'] = df['indice_governanca'].apply(funcao_classe_ig)

# %%
df.sample(5)
# Out:
#         regiao estado              municipio  codigo_mun  capital  \
# 1554   SUDESTE     MG               CLARAVAL     3116407        0
# 3815       SUL     PR      SAUDADE DO IGUACU     4126272        0
# 5241  NORDESTE     SE      RIACHAO DO DANTAS     2805802        0
# 1872  NORDESTE     PI      RIBEIRO GONCALVES     2208908        0
# 3669       SUL     RS  LAGOA DOS TRES CANTOS     4311270        0
#
#                 porte  populacao     area  densidade_dem        pib  ...  \
# 1554  Pequeno porte 1     4824.0   227.63      21.192286   67566.39  ...
# 3815  Pequeno porte 1     5410.0   152.09      35.571043  857862.74  ...
# 5241  Pequeno porte 1    19995.0   531.70      37.605793  154649.21  ...
# 1872  Pequeno porte 1     7185.0  3978.95       1.805753  187056.18  ...
# 3669  Pequeno porte 1     1649.0   138.64      11.894114   69853.22  ...
#
#       nota_humanas  nota_linguagem    nota_mat  nota_redacao   idhm  \
# ...

# %%
df['gasto_educacao_saude'] = df.apply(lambda x: x['gasto_pc_educacao']+x['gasto_pc_saude'], axis=1)
df.sample(5)
# Out:
#         regiao estado          municipio  codigo_mun  capital  \
# 5054  NORDESTE     PI           FLORIANO     2203909        0
# 674        SUL     SC            XANXERE     4219507        0
# 3106  NORDESTE     PE               IATI     2606507        0
# 4060  NORDESTE     PI  SAO JOSE DO PIAUI     2210201        0
# 925        SUL     SC     SAO BERNARDINO     4215752        0
#
#                 porte  populacao     area  densidade_dem         pib  ...  \
# 5054      Médio porte    58892.0  3409.65      17.272154   786093.32  ...
# 674   Pequeno porte 2    49057.0   377.76     129.862876  1267385.16  ...
# 3106  Pequeno porte 1    19056.0   635.14      30.002834   103861.60  ...
# 4060  Pequeno porte 1     6606.0   364.95      18.101110    35426.00  ...
# 925   Pequeno porte 1     2496.0   149.02      16.749430    53813.21  ...
#
#       nota_linguagem    nota_mat  nota_redacao   idhm  ranking_igm  \
# 5054      495.940751  469.265992    513.805395  0.613          NaN
# ...

# %% [markdown]
# # Ordenacao e  Agrupamento
#
#
#
# *  df.sort_values(by="coluna", ascending=False) ou .sort_values(by=['coluna1', 'coluna2'])
# *  df.value_counts()
# *  groupby: df.groupby("estado")
# *  agg: df["indice_governanca"].agg([np.mean, max, min])

# %%
df.groupby("estado")[["gasto_pc_educacao","gasto_pc_saude"]].mean().reset_index()
# Out:
#    estado  gasto_pc_educacao  gasto_pc_saude
# 0      AC         887.320909      276.802727
# 1      AL         861.551719      493.260781
# 2      AM         768.812963      347.299259
# 3      AP         630.400000      262.530000
# 4      BA         786.628919      404.896432
# 5      CE         759.448820      443.247022
# 6      DF        2077.490000     1982.450000
# 7      ES         760.962121      563.994328
# 8      GO         776.123785      710.820282
# 9      MA         911.721698      364.879182
# 10     MG         591.186976      603.457032
# 11     MS         848.331918      747.668219
# 12     MT         732.963130      683.356696
# 13     PA         842.765147      399.621176
# 14     PB         798.957374      547.662424
# 15     PE         658.929286      383.730824
# 16     PI         859.007817      493.178477
# 17     PR         691.591741      702.140739
# 18     RJ         827.354286      927.733968
# 19     RN         830.710000      605.208952
# ...

# %%
df.groupby("estado")[["gasto_pc_educacao","gasto_pc_saude"]].agg([min, max, sum, np.mean, len]).reset_index()
# Out:
#    estado gasto_pc_educacao                                        \
#                         min      max        sum         mean  len
# 0      AC            355.15  1439.06    9760.53   887.320909   22
# 1      AL            254.86  1530.27   55139.31   861.551719  102
# 2      AM            272.88  2706.52   41515.90   768.812963   62
# 3      AP            373.11   824.54    1891.20   630.400000   16
# 4      BA             56.60  2810.07  291052.70   786.628919  417
# 5      CE            382.80  1298.59  135181.89   759.448820  184
# 6      DF           2077.49  2077.49    2077.49  2077.490000    1
# 7      ES            447.40  2109.79   50223.50   760.962121   78
# 8      GO            280.65  1666.97  166090.49   776.123785  246
# 9      MA            400.69  1979.33  144963.75   911.721698  217
# 10     MG            254.87  3695.93  426245.81   591.186976  853
# 11     MS            374.68  1699.10   61928.23   848.331918   79
# ...

# %%
# índice composto
df.groupby(["estado","porte"])[["gasto_pc_educacao","gasto_pc_saude"]].agg([min, max, sum, np.mean, len]).reset_index()
# Out:
#     estado            porte gasto_pc_educacao                                  \
#                                           min      max       sum         mean
# 0       AC     Grande porte            355.15   355.15    355.15   355.150000
# 1       AC      Médio porte            577.08   577.08    577.08   577.080000
# 2       AC  Pequeno porte 1            574.86  1439.06   7493.51  1070.501429
# 3       AC  Pequeno porte 2            499.24   835.55   1334.79   667.395000
# 4       AL     Grande porte            254.86   416.11    670.97   335.485000
# ..     ...              ...               ...      ...       ...          ...
# 98      SP  Pequeno porte 2            253.46  2180.99  88008.14   792.866126
# 99      TO     Grande porte            564.24   722.56   1286.80   643.400000
# 100     TO      Médio porte            583.56  1045.53   1629.09   814.545000
# 101     TO  Pequeno porte 1            428.22  2384.95  90544.25   794.247807
# ...

# %%
data = df
data.loc[0,'gasto_pc_educacao'] = 'xxx'

# %%
data['gasto_pc_educacao']
# Out:
# 0           xxx
# 1       1704.93
# 2       1370.96
# 3        770.79
# 4       2077.49
#          ...
# 5565        NaN
# 5566        NaN
# 5567        NaN
# 5568        NaN
# 5569        NaN
# Name: gasto_pc_educacao, Length: 5570, dtype: object

# %%
data.groupby(["estado","porte"])[["gasto_pc_educacao","gasto_pc_saude"]].agg([min, max, sum, np.mean, len]).reset_index()
# Out:
# <ipython-input-28-8c173a010869>:1: FutureWarning: ['gasto_pc_educacao'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   data.groupby(["estado","porte"])[["gasto_pc_educacao","gasto_pc_saude"]].agg([min, max, sum, np.mean, len]).reset_index()
#     estado            porte gasto_pc_saude
#                                        min      max       sum        mean  len
# 0       AC     Grande porte         281.51   281.51    281.51  281.510000    1
# 1       AC      Médio porte         297.43   297.43    297.43  297.430000    1
# 2       AC  Pequeno porte 1         201.88   412.01   1955.36  279.337143   15
# 3       AC  Pequeno porte 2         244.61   265.92    510.53  255.265000    5
# 4       AL     Grande porte         509.45   720.74   1230.19  615.095000    2
# ..     ...              ...            ...      ...       ...         ...  ...
# ...

# %% [markdown]
# #Combinando dataframes
#
# *   concat
# *   join
# *   merge

# %%
df_ac = df.loc[df['estado']=="AC"]
df_pb = df.loc[df['estado']=="PB"]

# %%
df_ac.head()
# Out:
#      regiao estado             municipio  codigo_mun  capital  \
# 642   NORTE     AC            RIO BRANCO     1200401        1
# 2803  NORTE     AC              TARAUACA     1200609        0
# 3297  NORTE     AC  MARECHAL THAUMATURGO     1200351        0
# 3421  NORTE     AC                 FEIJO     1200302        0
# 3576  NORTE     AC            PORTO ACRE     1200807        0
#
#                 porte  populacao      area  densidade_dem         pib  ...  \
# 642      Grande porte   377057.0   8835.52      42.675134  6767742.57  ...
# 2803  Pequeno porte 2    39427.0  20171.07       1.954631   335400.69  ...
# 3297  Pequeno porte 1    17401.0   8191.69       2.124226   146204.80  ...
# 3421  Pequeno porte 2    32372.0  27975.43       1.157158   267468.97  ...
# 3576  Pequeno porte 1    17111.0   2604.88       6.568825   172551.06  ...
#
#       nota_linguagem    nota_mat  nota_redacao   idhm  ranking_igm  \
# 642       507.136405  458.999751    514.647779  0.678         643º
# ...

# %%
pd.concat([df_ac, df_pb])
# Out:
#         regiao estado             municipio  codigo_mun  capital  \
# 642      NORTE     AC            RIO BRANCO     1200401        1
# 2803     NORTE     AC              TARAUACA     1200609        0
# 3297     NORTE     AC  MARECHAL THAUMATURGO     1200351        0
# 3421     NORTE     AC                 FEIJO     1200302        0
# 3576     NORTE     AC            PORTO ACRE     1200807        0
# ...        ...    ...                   ...         ...      ...
# 4966  NORDESTE     PB       JUNCO DO SERIDO     2507804        0
# 4967  NORDESTE     PB           OLHO D'AGUA     2510402        0
# 4968  NORDESTE     PB                PILOES     2511608        0
# 4969  NORDESTE     PB   SAO MIGUEL DE TAIPU     2515005        0
# 4970  NORDESTE     PB               TENORIO     2516755        0
#
#                 porte  populacao      area  densidade_dem         pib  ...  \
# 642      Grande porte   377057.0   8835.52      42.675134  6767742.57  ...
# ...

# %%
df_ac_demograficos = df_ac[["regiao", "estado", "municipio", "populacao", "area", "densidade_dem"]]

df_ac_saude = df_ac[["regiao", "estado", "municipio", "jornada_trabalho", "gasto_pc_saude", "hab_p_medico"]]

# %%
df_ac_demograficos.head()
# Out:
#      regiao estado             municipio  populacao      area  densidade_dem
# 642   NORTE     AC            RIO BRANCO   377057.0   8835.52      42.675134
# 2803  NORTE     AC              TARAUACA    39427.0  20171.07       1.954631
# 3297  NORTE     AC  MARECHAL THAUMATURGO    17401.0   8191.69       2.124226
# 3421  NORTE     AC                 FEIJO    32372.0  27975.43       1.157158
# 3576  NORTE     AC            PORTO ACRE    17111.0   2604.88       6.568825

# %%
df_ac_saude.head()
# Out:
#      regiao estado             municipio  jornada_trabalho  gasto_pc_saude  \
# 642   NORTE     AC            RIO BRANCO         40.751454          281.51
# 2803  NORTE     AC              TARAUACA         39.203793          265.92
# 3297  NORTE     AC  MARECHAL THAUMATURGO         26.973651          246.01
# 3421  NORTE     AC                 FEIJO         30.788604             NaN
# 3576  NORTE     AC            PORTO ACRE         36.477009             NaN
#
#       hab_p_medico
# 642    2799.446154
# 2803   3820.100000
# 3297   2047.500000
# 3421   3599.777778
# 3576           NaN

# %%
df_ac_demograficos.join(df_ac_saude, lsuffix='_A', rsuffix='_B')
# Out:
#      regiao_A estado_A           municipio_A  populacao      area  \
# 642     NORTE       AC            RIO BRANCO   377057.0   8835.52
# 2803    NORTE       AC              TARAUACA    39427.0  20171.07
# 3297    NORTE       AC  MARECHAL THAUMATURGO    17401.0   8191.69
# 3421    NORTE       AC                 FEIJO    32372.0  27975.43
# 3576    NORTE       AC            PORTO ACRE    17111.0   2604.88
# 3959    NORTE       AC      SENADOR GUIOMARD    21369.0   2321.45
# 4278    NORTE       AC           MANCIO LIMA    17545.0   5452.85
# 4348    NORTE       AC                JORDAO     7685.0   5357.28
# 4349    NORTE       AC          PORTO WALTER    11059.0   6443.83
# 4350    NORTE       AC   SANTA ROSA DO PURUS     6021.0   6145.61
# 4351    NORTE       AC       RODRIGUES ALVES    17464.0   3076.95
# 4352    NORTE       AC     PLACIDO DE CASTRO    18336.0   1943.25
# 4353    NORTE       AC       CRUZEIRO DO SUL    82075.0   8779.40
# ...

# %%
df_ac_demograficos.head()
# Out:
#      regiao estado             municipio  populacao      area  densidade_dem
# 642   NORTE     AC            RIO BRANCO   377057.0   8835.52      42.675134
# 2803  NORTE     AC              TARAUACA    39427.0  20171.07       1.954631
# 3297  NORTE     AC  MARECHAL THAUMATURGO    17401.0   8191.69       2.124226
# 3421  NORTE     AC                 FEIJO    32372.0  27975.43       1.157158
# 3576  NORTE     AC            PORTO ACRE    17111.0   2604.88       6.568825

# %%
df_ac_saude.head()
# Out:
#      regiao estado             municipio  jornada_trabalho  gasto_pc_saude  \
# 642   NORTE     AC            RIO BRANCO         40.751454          281.51
# 2803  NORTE     AC              TARAUACA         39.203793          265.92
# 3297  NORTE     AC  MARECHAL THAUMATURGO         26.973651          246.01
# 3421  NORTE     AC                 FEIJO         30.788604             NaN
# 3576  NORTE     AC            PORTO ACRE         36.477009             NaN
#
#       hab_p_medico
# 642    2799.446154
# 2803   3820.100000
# 3297   2047.500000
# 3421   3599.777778
# 3576           NaN

# %%
# poderia usar left_on e right_on caso a nomenclatura das colunas fosse diferente

df_ac_demograficos.merge(df_ac_saude, on=["regiao","estado","municipio"])
# Out:
#    regiao estado             municipio  populacao      area  densidade_dem  \
# 0   NORTE     AC            RIO BRANCO   377057.0   8835.52      42.675134
# 1   NORTE     AC              TARAUACA    39427.0  20171.07       1.954631
# 2   NORTE     AC  MARECHAL THAUMATURGO    17401.0   8191.69       2.124226
# 3   NORTE     AC                 FEIJO    32372.0  27975.43       1.157158
# 4   NORTE     AC            PORTO ACRE    17111.0   2604.88       6.568825
# 5   NORTE     AC      SENADOR GUIOMARD    21369.0   2321.45       9.205023
# 6   NORTE     AC           MANCIO LIMA    17545.0   5452.85       3.217583
# 7   NORTE     AC                JORDAO     7685.0   5357.28       1.434497
# 8   NORTE     AC          PORTO WALTER    11059.0   6443.83       1.716215
# 9   NORTE     AC   SANTA ROSA DO PURUS     6021.0   6145.61       0.979724
# 10  NORTE     AC       RODRIGUES ALVES    17464.0   3076.95       5.675750
# ...

# %% [markdown]
# ## Obtendo Diferença entre DataFrames

# %%
df_ac_a = df_ac.iloc[:5]
df_ac_b = df_ac.iloc[3:7]

# %%
df_ac_a

# %%
df_ac_b

# %% [markdown]
# # Verificando Correlação Entre Variáveis

# %% [markdown]
# Instalando biblioteca Seaborn:

# %%
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import seaborn as sns

# %%
matriz_cor = df[['nota_mat','nota_redacao','gasto_pc_saude','gasto_pc_educacao','idhm']].corr(numeric_only=True)
matriz_cor
# Out:
#                 nota_mat  nota_redacao  gasto_pc_saude      idhm
# nota_mat        1.000000      0.699608        0.219897  0.681088
# nota_redacao    0.699608      1.000000        0.126119  0.489982
# gasto_pc_saude  0.219897      0.126119        1.000000  0.413365
# idhm            0.681088      0.489982        0.413365  1.000000

# %% [markdown]
# Exibindo tabela acima utilizando mapa de calor:

# %%
sns.heatmap(matriz_cor, annot=True, fmt=".3f")
# Out:
# <Axes: >

# %% [markdown]
# Exibindo gráfico de dispersão:

# %%
df.plot(kind = 'scatter', x = 'idhm', y = 'nota_mat')
plt.show()

# %% [markdown]
# Utilizando `lmplot` ou, linear model plot, podemos traçar uma linha representando a correlação.

# %%
sns.lmplot(x="idhm", y="nota_mat", data=df.sample(1000))

# %%
df_ac = df[df["estado"] == "AC"]
df_ac
# Out:
#      regiao estado             municipio  codigo_mun  capital  \
# 642   NORTE     AC            RIO BRANCO     1200401        1
# 2803  NORTE     AC              TARAUACA     1200609        0
# 3297  NORTE     AC  MARECHAL THAUMATURGO     1200351        0
# 3421  NORTE     AC                 FEIJO     1200302        0
# 3576  NORTE     AC            PORTO ACRE     1200807        0
# 3959  NORTE     AC      SENADOR GUIOMARD     1200450        0
# 4278  NORTE     AC           MANCIO LIMA     1200336        0
# 4348  NORTE     AC                JORDAO     1200328        0
# 4349  NORTE     AC          PORTO WALTER     1200393        0
# 4350  NORTE     AC   SANTA ROSA DO PURUS     1200435        0
# 4351  NORTE     AC       RODRIGUES ALVES     1200427        0
# 4352  NORTE     AC     PLACIDO DE CASTRO     1200385        0
# 4353  NORTE     AC       CRUZEIRO DO SUL     1200203        0
# 4354  NORTE     AC        SENA MADUREIRA     1200500        0
# ...

# %%
sns.lmplot(x="idhm", y="nota_mat", data=df_ac)

# %%
df_estados = df[df["estado"].isin(["AC", "AM"])]

# %%
sns.lmplot(x="idhm", y="nota_mat", hue="estado", data=df_estados)

# %% [markdown]
# # Tratando Strings - Retirando espaços e acentos

# %%
df['mun'] = df['municipio'].str.replace(' ','')

# %%
df['mun']

# %% [markdown]
# ### Resolve problemas de formato de texto

# %%
df['mun2'] = df['municipio'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
df[df['mun2'] == df["municipio"]][['mun','mun2','municipio']]

# %% [markdown]
# # Salvar o DataFrame em CSV

# %%
df.to_csv("igm_tratado.csv")
#verificar o path do caminho
