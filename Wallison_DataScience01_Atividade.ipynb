# %% [markdown]
# <a href="https://colab.research.google.com/github/wallisonferreira/data-science-tce/blob/main/Wallison_DataScience01_Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade - Índices de tendência central e de dispersão

# %% [markdown]
# ### A base de dados a ser utilizada, adults.csv, é um extrato do censo estadunidense de 1994. Baixe aqui: https://drive.google.com/file/d/1paZ1q0z5B7BOiwlFIrq9_qIzwHO6hGdu/view?usp=sharing
# A base é composta por 15 atributos:
# * age (idade): continuo.
# * workclass (classe de trabalho): Private, Self­emp­not­inc, Self­emp­inc, Federal­gov, Local­gov, State­gov, Without­pay, Never­worked.
# * fnlwgt: continuous. (meio complicado de explicar o significado. Mais em http://web.cs.wpi.edu/~cs4341/C00/Projects/fnlwgt)
# * education (nível de educação): Bachelors, Some­college, 11th, HS­grad, Prof­school, Assoc­acdm, Assoc­voc, 9th, 7th­8th, 12th, Masters, 1st­4th, 10th, Doctorate, 5th­6th, Preschool.
# * education­num (código para o nível educacional): continuous.
# * marital­status (estado civil): Married­civ­spouse, Divorced, Never­married, Separated, Widowed, Married­spouse­absent, Married­AF­spouse.
# * occupation (profissão): Tech­support, Craft­repair, Other­service, Sales, Exec­managerial, Prof­specialty, Handlers­cleaners, Machine­op­inspct, Adm­clerical, Farming­fishing, Transport­moving, Priv­house­serv, Protective­serv, Armed­Forces.
# * relationship: Wife, Own­child, Husband, Not­in­family, Other­relative, Unmarried.
# * race (etnia): White, Asian­Pac­Islander, Amer­Indian­Eskimo, Other, Black.
# * sex (gênero): Female, Male.
# * capital­gain (ganho de capital): continuous.
# * capital­loss (perda de capital): continuous.
# * hours­per­week (horas de trabalho por semana): continuous.
# * native­country (país de origem): United­States, Cambodia, England, Puerto­Rico, Canada, Germany, Outlying­US(Guam­USVI­etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican­Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El­Salvador, Trinadad&Tobago, Peru, Hong, Holand­Netherlands.
# * Class (Classe): ­ se ganhou mais ou menos que US$ 50.000,00
# * Wages (salário): o salário percebido naquele ano.

# %% [markdown]
# ### De posse desses dados, espera­se que você sumarize (utilizando todos os métodos estudados) os valores dos atributos idade, wages, capitalgain e capitalloss. Identifique qual métrica você considera ser, com base no assunto estudado, a mais adequada como índice de tendência central.

# %%
import pandas as pd
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/CiênciaDeDadosTCE/adult.csv", encoding='latin1')
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relasionship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country   class  \
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'],7, edgecolor='black')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Em seguida, identifique qual profissão, gênero, cor, país de origem e nível educacional possuem maior média salarial.

# %%
# remove espaços entre o nome das colunas
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relasionship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'class', 'Wages'],
#       dtype='object')

# %%
def whoIsGreater(dataframe, column_name, value):
    return dataframe[dataframe[column_name] == value]

# %%
maior = media.max()
maior.item()
# Out:
# 50230.467535661584

# %% [markdown]
# ##### Salário por profissão

# %%
occupation = df[['occupation','Wages']].groupby(['occupation']).mean()
maior = occupation.max()
greater = whoIsGreater(media, 'Wages', maior.item())
print('A profissão com a maior média é ' + str(greater.index[0]) + ' com Salário médio de ' + str(greater.Wages.values[0]))
occupation.plot.barh(figsize=(12,8), color='#023047');
# Out:
# A profissão com a maior média é  Exec-managerial com Salário médio de 50230.467535661584

# %% [markdown]
# ##### Salário por sexo

# %%
sex.plot.pie()

# %%
sex = df[['sex','Wages']].groupby(['sex']).mean()
maior = sex.max()
greater = whoIsGreater(sex, 'Wages', maior.item())
print('O gênero com a maior média é ' + str(greater.index[0]) + ' com Salário médio de ' + str(greater.Wages.values[0]))
sex.plot.pie(subplots=True, figsize=(12,8), colors=['#2ec4b6','#09AEFB'], labels=['Female','Male'], startangle=270);
# Out:
# O gênero com a maior média é  Male com Salário médio de 41900.9947223497

# %% [markdown]
# ##### Salário por cor

# %%
race = df[['race','Wages']].groupby(['race']).mean()
maior = race.max()
greater = whoIsGreater(race, 'Wages', maior.item())
print('A cor com a maior média é ' + str(greater.index[0]) + ' com Salário médio de ' + str(greater.Wages.values[0]))
race.plot.barh(figsize=(12,8), color='#023047');
# Out:
# A cor com a maior média é  Asian-Pac-Islander com Salário médio de 40127.47353224254

# %% [markdown]
# ##### Salário por país de origem

# %%
country = df[['native-country','Wages']].groupby(['native-country']).mean()
maior = country.max()
greater = whoIsGreater(country, 'Wages', maior.item())
print('O país com a maior média é ' + str(greater.index[0]) + ' com Salário médio de ' + str(greater.Wages.values[0]))
country.plot.bar(figsize=(12,8), color='#023047');
# Out:
# O país com a maior média é  Cambodia com Salário médio de 49261.42105263158

# %% [markdown]
# ##### Salário por nível educacional

# %%
education = df[['education','Wages']].groupby(['education']).mean()
maior = education.max()
greater = whoIsGreater(education, 'Wages', maior.item())
print('O gênero com a maior média é ' + str(greater.index[0]) + ' com Salário médio de ' + str(greater.Wages.values[0]))
education.plot.barh(figsize=(12,8), color='#023047');
# Out:
# O gênero com a maior média é  Doctorate com Salário médio de 63161.02905569007

# %% [markdown]
# ### Gere os boxplots de todos os atributos numéricos.

# %%
import matplotlib.pyplot as plt
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relasionship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  class           32561 non-null  object
#  15  Wages           32561 non-null  int64
# dtypes: int64(7), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# ##### Boxplot Idade

# %%
from matplotlib import pyplot
import seaborn as sns

# %%
figsize_boxplot = (12, 10)
fig, ax = pyplot.subplots(figsize=figsize_boxplot)
sns.boxplot(data=df.age, ax=ax, palette=['#264653','#2a9d8f','#e9c46a','#f4a261','#e76f51'],fliersize=5);

ax.set_title('Distribuição da Idade', fontsize=20)
ax.set_xlabel('Idade', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

sns.set_style('whitegrid')

quartis = df.age.quantile([0.25,0.5,0.75])
median = df.age.median()
whisker_low, whisker_high = ax.get_ylim()
whisker_low = max(whisker_low, quartis[0.25]-1.5*(quartis[0.75]-quartis[0.25]))
whisker_high = min(whisker_high, quartis[0.75]+1.5*(quartis[0.75]-quartis[0.25]))
ax.hlines(y=[quartis[0.25], median, quartis[0.75]], xmin=0, xmax=1, color='#2a9d8f', linestyle='-', linewidth=2)
ax.hlines(y=[whisker_low, whisker_high], xmin=0, xmax=1, color='#f4a261', linestyle='-', linewidth=2)
ax.plot([0.5], [df.age.mean()], marker='o', color='#e76f51', markersize=8)

ax.tick_params(labelsize=14)
ax.set_ylim(bottom=whisker_low, top=whisker_high)

plt.show()

# %% [markdown]
# ##### Boxplot FNLWGT

# %%
figsize_boxplot = (12, 10)
fig, ax = pyplot.subplots(figsize=figsize_boxplot)
sns.boxplot(data=df.fnlwgt, ax=ax, palette=['#264653','#2a9d8f','#e9c46a','#f4a261','#e76f51'],fliersize=5);

ax.set_title('Distribuição da FNLWGT', fontsize=20)
ax.set_xlabel('FNLWGT', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

sns.set_style('whitegrid')

quartis = df.age.quantile([0.25,0.5,0.75])
median = df.age.median()
whisker_low, whisker_high = ax.get_ylim()
whisker_low = max(whisker_low, quartis[0.25]-1.5*(quartis[0.75]-quartis[0.25]))
whisker_high = min(whisker_high, quartis[0.75]+1.5*(quartis[0.75]-quartis[0.25]))
ax.hlines(y=[quartis[0.25], median, quartis[0.75]], xmin=0, xmax=1, color='#2a9d8f', linestyle='-', linewidth=2)
ax.hlines(y=[whisker_low, whisker_high], xmin=0, xmax=1, color='#f4a261', linestyle='-', linewidth=2)
ax.plot([0.5], [df.age.mean()], marker='o', color='#e76f51', markersize=8)

ax.tick_params(labelsize=14)
ax.set_ylim(bottom=whisker_low, top=whisker_high)

plt.show()

# %% [markdown]
# ##### Boxplot Education-Num

# %%
figsize_boxplot = (12, 10)
fig, ax = pyplot.subplots(figsize=figsize_boxplot)
sns.boxplot(data=df['education-num'], ax=ax, palette=['#264653','#2a9d8f','#e9c46a','#f4a261','#e76f51'],fliersize=5);

ax.set_title('Distribuição da Educação', fontsize=20)
ax.set_xlabel('Educação', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

sns.set_style('whitegrid')

quartis = df.age.quantile([0.25,0.5,0.75])
median = df.age.median()
whisker_low, whisker_high = ax.get_ylim()
whisker_low = max(whisker_low, quartis[0.25]-1.5*(quartis[0.75]-quartis[0.25]))
whisker_high = min(whisker_high, quartis[0.75]+1.5*(quartis[0.75]-quartis[0.25]))
ax.hlines(y=[quartis[0.25], median, quartis[0.75]], xmin=0, xmax=1, color='#2a9d8f', linestyle='-', linewidth=2)
ax.hlines(y=[whisker_low, whisker_high], xmin=0, xmax=1, color='#f4a261', linestyle='-', linewidth=2)
ax.plot([0.5], [df.age.mean()], marker='o', color='#e76f51', markersize=8)

ax.tick_params(labelsize=14)
ax.set_ylim(bottom=whisker_low, top=whisker_high)

plt.show()

# %% [markdown]
# ##### Boxplot Capital Gain

# %%
figsize_boxplot = (12, 10)
fig, ax = pyplot.subplots(figsize=figsize_boxplot)
sns.boxplot(data=df['capital-gain'], ax=ax, palette=['#264653','#2a9d8f','#e9c46a','#f4a261','#e76f51'],fliersize=5);

ax.set_title('Distribuição de Capital Gain', fontsize=20)
ax.set_xlabel('Capital Gain', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

sns.set_style('whitegrid')

quartis = df.age.quantile([0.25,0.5,0.75])
median = df.age.median()
whisker_low, whisker_high = ax.get_ylim()
whisker_low = max(whisker_low, quartis[0.25]-1.5*(quartis[0.75]-quartis[0.25]))
whisker_high = min(whisker_high, quartis[0.75]+1.5*(quartis[0.75]-quartis[0.25]))
ax.hlines(y=[quartis[0.25], median, quartis[0.75]], xmin=0, xmax=1, color='#2a9d8f', linestyle='-', linewidth=2)
ax.hlines(y=[whisker_low, whisker_high], xmin=0, xmax=1, color='#f4a261', linestyle='-', linewidth=2)
ax.plot([0.5], [df.age.mean()], marker='o', color='#e76f51', markersize=8)

ax.tick_params(labelsize=14)
ax.set_ylim(bottom=whisker_low, top=whisker_high)

plt.show()

# %% [markdown]
# ##### Boxplot Capital Loss

# %%
figsize_boxplot = (12, 10)
fig, ax = pyplot.subplots(figsize=figsize_boxplot)
sns.boxplot(data=df['capital-loss'], ax=ax, palette=['#264653','#2a9d8f','#e9c46a','#f4a261','#e76f51'],fliersize=5);

ax.set_title('Distribuição de Capital Loss', fontsize=20)
ax.set_xlabel('Capital Loss', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

sns.set_style('whitegrid')

quartis = df.age.quantile([0.25,0.5,0.75])
median = df.age.median()
whisker_low, whisker_high = ax.get_ylim()
whisker_low = max(whisker_low, quartis[0.25]-1.5*(quartis[0.75]-quartis[0.25]))
whisker_high = min(whisker_high, quartis[0.75]+1.5*(quartis[0.75]-quartis[0.25]))
ax.hlines(y=[quartis[0.25], median, quartis[0.75]], xmin=0, xmax=1, color='#2a9d8f', linestyle='-', linewidth=2)
ax.hlines(y=[whisker_low, whisker_high], xmin=0, xmax=1, color='#f4a261', linestyle='-', linewidth=2)
ax.plot([0.5], [df.age.mean()], marker='o', color='#e76f51', markersize=8)

ax.tick_params(labelsize=14)
ax.set_ylim(bottom=whisker_low, top=whisker_high)

plt.show()

# %% [markdown]
# ##### Hours Per Week

# %%
figsize_boxplot = (12, 10)
fig, ax = pyplot.subplots(figsize=figsize_boxplot)
sns.boxplot(data=df['hours-per-week'], ax=ax, palette=['#264653','#2a9d8f','#e9c46a','#f4a261','#e76f51'],fliersize=5);

ax.set_title('Distribuição da Horas Por Semana', fontsize=20)
ax.set_xlabel('Horas Por Semana', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

sns.set_style('whitegrid')

quartis = df.age.quantile([0.25,0.5,0.75])
median = df.age.median()
whisker_low, whisker_high = ax.get_ylim()
whisker_low = max(whisker_low, quartis[0.25]-1.5*(quartis[0.75]-quartis[0.25]))
whisker_high = min(whisker_high, quartis[0.75]+1.5*(quartis[0.75]-quartis[0.25]))
ax.hlines(y=[quartis[0.25], median, quartis[0.75]], xmin=0, xmax=1, color='#2a9d8f', linestyle='-', linewidth=2)
ax.hlines(y=[whisker_low, whisker_high], xmin=0, xmax=1, color='#f4a261', linestyle='-', linewidth=2)
ax.plot([0.5], [df.age.mean()], marker='o', color='#e76f51', markersize=8)

ax.tick_params(labelsize=14)
ax.set_ylim(bottom=whisker_low, top=whisker_high)

plt.show()

# %% [markdown]
# ##### Wages

# %%
figsize_boxplot = (12, 10)
fig, ax = pyplot.subplots(figsize=figsize_boxplot)
sns.boxplot(data=df['Wages'], ax=ax, palette=['#264653','#2a9d8f','#e9c46a','#f4a261','#e76f51'],fliersize=5);

ax.set_title('Distribuição de Salários', fontsize=20)
ax.set_xlabel('Salários', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

sns.set_style('whitegrid')

quartis = df.age.quantile([0.25,0.5,0.75])
median = df.age.median()
whisker_low, whisker_high = ax.get_ylim()
whisker_low = max(whisker_low, quartis[0.25]-1.5*(quartis[0.75]-quartis[0.25]))
whisker_high = min(whisker_high, quartis[0.75]+1.5*(quartis[0.75]-quartis[0.25]))
ax.hlines(y=[quartis[0.25], median, quartis[0.75]], xmin=0, xmax=1, color='#2a9d8f', linestyle='-', linewidth=2)
ax.hlines(y=[whisker_low, whisker_high], xmin=0, xmax=1, color='#f4a261', linestyle='-', linewidth=2)
ax.plot([0.5], [df.age.mean()], marker='o', color='#e76f51', markersize=8)

ax.tick_params(labelsize=14)
ax.set_ylim(bottom=whisker_low, top=whisker_high)

plt.show()
